# %% [markdown]
# <a href="https://colab.research.google.com/github/iam-fern/real_data/blob/main/CHNS_pexam_pub_12_U24BU23U36U236_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
from google.colab import files
import pandas as pd
import numpy as np
import scipy as sp
import math
import matplotlib.pyplot as plt
from scipy.stats import norm
from numpy.random import normal
import statistics
import statistics as stats
import scipy.stats as ss
from scipy import stats
import scipy.stats as stats
import random
import statsmodels.api as sm
# %matplotlib inline
from google.colab import files
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# where your file is located
FILE_LOCATION = '/content/drive/My Drive/pattern_realdata/pexam_pub_12.sas7bdat'

# %%
df = pd.read_sas(FILE_LOCATION)
df
#df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/io/sas/sas7bdat.py:800: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   rslt[name] = self._byte_chunk[jb, :].view(dtype=self.byte_order + "d")
#                IDind  U25   U26  U27   U28    U29  U34  U35  U36  U424  ...  \
# 0       1.111010e+11  0.0   NaN  NaN   NaN    NaN  1.0  1.0  3.0   0.0  ...
# 1       1.111010e+11  1.0  28.0  0.0   NaN  360.0  NaN  NaN  NaN   NaN  ...
# 2       1.111010e+11  0.0   NaN  NaN   NaN    NaN  1.0  1.0  3.0   0.0  ...
# 3       1.111010e+11  0.0   NaN  NaN   NaN    NaN  NaN  NaN  NaN   NaN  ...
# 4       1.111010e+11  0.0   NaN  NaN   NaN    NaN  0.0  NaN  NaN   1.0  ...
# ...              ...  ...   ...  ...   ...    ...  ...  ...  ...   ...  ...
# 126403  5.523040e+11  NaN   NaN  NaN   NaN    NaN  NaN  NaN  NaN   NaN  ...
# 126404  5.523042e+11  1.0  18.0  1.0  12.0    NaN  NaN  NaN  NaN   NaN  ...
# 126405  5.523042e+11  NaN   NaN  NaN   NaN    NaN  NaN  NaN  NaN   NaN  ...
# 126406  5.523042e+11  NaN   NaN  NaN   NaN    NaN  NaN  NaN  NaN   NaN  ...
# 126407  5.523042e+11  NaN   NaN  NaN   NaN    NaN  NaN  NaN  NaN   NaN  ...
#
#         U16  U17  U18  U19  U1D  CM1  U7_91  U8_91  U9_91  temp
# 0       0.0  0.0  0.0  0.0  NaN  NaN    NaN    NaN    NaN   NaN
# 1       NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN    NaN  36.4
# 2       0.0  0.0  0.0  0.0  NaN  NaN    NaN    NaN    NaN   NaN
# 3       NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN    NaN  36.4
# 4       0.0  0.0  0.0  0.0  NaN  NaN    NaN    NaN    NaN   NaN
# ...     ...  ...  ...  ...  ...  ...    ...    ...    ...   ...
# 126403  0.0  0.0  0.0  0.0  NaN  NaN    NaN    NaN    NaN  36.7
# 126404  0.0  0.0  0.0  0.0  NaN  NaN    NaN    NaN    NaN  37.0
# 126405  0.0  0.0  0.0  0.0  NaN  NaN    NaN    NaN    NaN  37.1
# 126406  0.0  0.0  0.0  0.0  NaN  NaN    NaN    NaN    NaN  37.0
# 126407  0.0  0.0  0.0  0.0  NaN  NaN    NaN    NaN    NaN  37.0
#
# [126408 rows x 159 columns]

# %% [markdown]
# ###### **U23** #OF YEARS HAD HIGH BLOOD PRESSURE ปีมีความดันโลหิตสูง
# ###### **U24B** AGE (YEARS) AT DIABETES DIAGNOSIS อายุ (ปี) ที่การวินิจฉัยโรคเบาหวาน
# ###### **U36** AVG # OF CUPS OF TEA DRINKS PER DAY จำนวนเครื่องดื่มชาเฉลี่ยต่อวัน
# ###### **U39** AVG #OF CUPS OF COFFEE DRINKS PER DAY จำนวนดื่มกาแฟเฉลี่ยต่อวัน
# ###### **U42** BEER: #OF BOTTLES DRINKS EACH WEEK จำนวนดื่มเบียร์เฉลี่ยทุกสัปดาห์
# ###### **U236** SUGARED FRUIT DRINKS PER WEEK เครื่องดื่มผลไม้รสหวานต่อสัปดาห์

# %%
table = df[['IDind', 'U24B', 'U23', 'U36', 'U236']]
table
# Out:
#                IDind  U24B   U23  U36  U236
# 0       1.111010e+11   NaN  30.0  3.0   NaN
# 1       1.111010e+11   NaN  40.0  NaN   NaN
# 2       1.111010e+11  62.0  35.0  3.0   NaN
# 3       1.111010e+11  38.0  40.0  NaN   NaN
# 4       1.111010e+11   NaN   1.0  NaN   NaN
# ...              ...   ...   ...  ...   ...
# 126403  5.523040e+11   NaN   NaN  NaN   NaN
# 126404  5.523042e+11   NaN   NaN  NaN   NaN
# 126405  5.523042e+11   NaN   NaN  NaN   NaN
# 126406  5.523042e+11   NaN   NaN  NaN   NaN
# 126407  5.523042e+11   NaN   NaN  NaN   NaN
#
# [126408 rows x 5 columns]

# %%
# Define in which columns to look for missing values.
table1 = table.dropna(subset=['U24B', 'U23', 'U36', 'U236'])
table1
# Out:
#                IDind  U24B   U23  U36  U236
# 683     1.112040e+11  63.0  10.0  5.0   0.2
# 693     1.112040e+11  70.0   5.0  1.0   0.1
# 694     1.112040e+11  60.0  10.0  4.0   0.1
# 1129    1.113040e+11  50.0   7.0  2.0   0.2
# 1646    1.121010e+11  56.0   3.0  8.0   0.1
# 1708    1.121020e+11  12.0  12.0  3.0   1.0
# 13623   2.311010e+11  52.0  10.0  4.0   0.1
# 24760   3.122020e+11  54.0  10.0  3.0   0.2
# 38461   3.224041e+11  70.0   3.0  2.0   0.9
# 40820   3.712011e+11  40.0  15.0  1.0   0.1
# 55498   4.121010e+11  52.0  30.0  3.0   1.0
# 66114   4.211030e+11  47.0   3.0  3.0   0.3
# 79935   4.311021e+11  73.0  13.0  8.0   0.1
# 80100   4.311030e+11  53.0  21.0  2.0   0.1
# 80101   4.311030e+11  54.0  23.0  1.0   0.5
# 80466   4.311030e+11  42.0  17.0  5.0  -0.9
# 80469   4.311030e+11  42.0  24.0  3.0   0.3
# 81191   4.312010e+11  40.0   6.0 -9.0  -0.9
# 81648   4.312020e+11 -99.0 -99.0  6.0   1.0
# 81911   4.312020e+11  57.0  10.0  5.0  -0.9
# 93076   4.511021e+11  46.0   3.0  2.0   0.7
# 94851   4.511051e+11  49.0  30.0  1.0   0.5
# 106970  4.524030e+11  66.0   2.0  3.0   0.1
# 123975  5.511030e+11  43.0  15.0  1.0   0.1

# %%
table1.mean()
# Out:
# IDind    3.372527e+11
# U24B     4.550000e+01
# U23      7.625000e+00
# U36      2.791667e+00
# U236     2.083333e-01
# dtype: float64

# %%
x = table1[['U23', 'U36', 'U236']]
y = table1["U24B"]
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
y_pred = model.predict(x)

df = pd.DataFrame({"Actual": y, "Predicted": y_pred})

table_data_new = pd.DataFrame({ "x1"    : table1["U23"],
                                "x2"    : table1["U36"],
                                'x3'    : table1['U236'],
                                "y"     : df["Actual"],
                                "y_hat" : df["Predicted"]})
table_data_new["e"] = table_data_new["y"] - table_data_new["y_hat"]
table_data_new
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#           x1   x2   x3     y      y_hat          e
# 683     10.0  5.0  0.2  63.0  50.980369  12.019631
# 693      5.0  1.0  0.1  70.0  41.295729  28.704271
# 694     10.0  4.0  0.1  60.0  50.658485   9.341515
# 1129     7.0  2.0  0.2  50.0  43.895184   6.104816
# 1646     3.0  8.0  0.1  56.0  47.578757   8.421243
# 1708    12.0  3.0  1.0  12.0  43.603585 -31.603585
# 13623   10.0  4.0  0.1  52.0  50.658485   1.341515
# 24760   10.0  3.0  0.2  54.0  48.534484   5.465516
# 38461    3.0  2.0  0.9  70.0  33.032631  36.967369
# 40820   15.0  1.0  0.1  40.0  52.683585 -12.683585
# 55498   30.0  3.0  1.0  52.0  64.101726 -12.101726
# 66114    3.0  3.0  0.3  47.0  39.661926   7.338074
# 79935   13.0  8.0  0.1  73.0  58.966613  14.033387
# 80100   21.0  2.0  0.1  53.0  60.739241  -7.739241
# 80101   23.0  1.0  0.5  54.0  58.189635  -4.189635
# 80466   17.0  5.0 -0.9  42.0  68.863514 -26.863514
# 80469   24.0  3.0  0.3  42.0  63.576423 -21.576423
# 81191    6.0 -9.0 -0.9  40.0  39.215676   0.784324
# 81648  -99.0  6.0  1.0 -99.0 -79.132788 -19.867212
# 81911   10.0  5.0 -0.9  57.0  60.892015  -3.892015
# 93076    3.0  2.0  0.7  46.0  34.834748  11.165252
# 94851   30.0  1.0  0.5  49.0  66.161134 -17.161134
# 106970   2.0  3.0  0.1  66.0  40.325258  25.674742
# 123975  15.0  1.0  0.1  43.0  52.683585  -9.683585

# %%
import numpy as np
import pandas as pd

# %%
data = table_data_new.loc[table_data_new["x1"] >= 0]
data
# Out:
#           x1   x2   x3     y      y_hat          e
# 683     10.0  5.0  0.2  63.0  50.980369  12.019631
# 693      5.0  1.0  0.1  70.0  41.295729  28.704271
# 694     10.0  4.0  0.1  60.0  50.658485   9.341515
# 1129     7.0  2.0  0.2  50.0  43.895184   6.104816
# 1646     3.0  8.0  0.1  56.0  47.578757   8.421243
# 1708    12.0  3.0  1.0  12.0  43.603585 -31.603585
# 13623   10.0  4.0  0.1  52.0  50.658485   1.341515
# 24760   10.0  3.0  0.2  54.0  48.534484   5.465516
# 38461    3.0  2.0  0.9  70.0  33.032631  36.967369
# 40820   15.0  1.0  0.1  40.0  52.683585 -12.683585
# 55498   30.0  3.0  1.0  52.0  64.101726 -12.101726
# 66114    3.0  3.0  0.3  47.0  39.661926   7.338074
# 79935   13.0  8.0  0.1  73.0  58.966613  14.033387
# 80100   21.0  2.0  0.1  53.0  60.739241  -7.739241
# 80101   23.0  1.0  0.5  54.0  58.189635  -4.189635
# 80466   17.0  5.0 -0.9  42.0  68.863514 -26.863514
# 80469   24.0  3.0  0.3  42.0  63.576423 -21.576423
# 81191    6.0 -9.0 -0.9  40.0  39.215676   0.784324
# 81911   10.0  5.0 -0.9  57.0  60.892015  -3.892015
# 93076    3.0  2.0  0.7  46.0  34.834748  11.165252
# 94851   30.0  1.0  0.5  49.0  66.161134 -17.161134
# 106970   2.0  3.0  0.1  66.0  40.325258  25.674742
# 123975  15.0  1.0  0.1  43.0  52.683585  -9.683585

# %%
data1 = data.loc[data["x2"] >= 0]
data1
# Out:
#           x1   x2   x3     y      y_hat          e
# 683     10.0  5.0  0.2  63.0  50.980369  12.019631
# 693      5.0  1.0  0.1  70.0  41.295729  28.704271
# 694     10.0  4.0  0.1  60.0  50.658485   9.341515
# 1129     7.0  2.0  0.2  50.0  43.895184   6.104816
# 1646     3.0  8.0  0.1  56.0  47.578757   8.421243
# 1708    12.0  3.0  1.0  12.0  43.603585 -31.603585
# 13623   10.0  4.0  0.1  52.0  50.658485   1.341515
# 24760   10.0  3.0  0.2  54.0  48.534484   5.465516
# 38461    3.0  2.0  0.9  70.0  33.032631  36.967369
# 40820   15.0  1.0  0.1  40.0  52.683585 -12.683585
# 55498   30.0  3.0  1.0  52.0  64.101726 -12.101726
# 66114    3.0  3.0  0.3  47.0  39.661926   7.338074
# 79935   13.0  8.0  0.1  73.0  58.966613  14.033387
# 80100   21.0  2.0  0.1  53.0  60.739241  -7.739241
# 80101   23.0  1.0  0.5  54.0  58.189635  -4.189635
# 80466   17.0  5.0 -0.9  42.0  68.863514 -26.863514
# 80469   24.0  3.0  0.3  42.0  63.576423 -21.576423
# 81911   10.0  5.0 -0.9  57.0  60.892015  -3.892015
# 93076    3.0  2.0  0.7  46.0  34.834748  11.165252
# 94851   30.0  1.0  0.5  49.0  66.161134 -17.161134
# 106970   2.0  3.0  0.1  66.0  40.325258  25.674742
# 123975  15.0  1.0  0.1  43.0  52.683585  -9.683585

# %%
#data_new = data.loc[data["e"] >= 0 ]
#data_new
# Out:
#           x1   x2     y      y_hat          e
# 2       35.0  3.0  62.0  59.820065   2.179935
# 18       7.0  3.0  60.0  46.064942  13.935058
# 22      10.0  3.0  54.0  47.538705   6.461295
# 23      30.0  2.0  60.0  58.128899   1.871101
# 207      4.0  6.0  49.0  42.295859   6.704141
# ...      ...  ...   ...        ...        ...
# 118535   2.0  3.0  62.0  43.608669  18.391331
# 122928  11.0  1.0  58.0  49.560172   8.439828
# 124292   3.0  1.0  73.0  45.630136  27.369864
# 125762   4.0  1.0  55.0  46.121391   8.878609
# 125978   4.0  5.0  65.0  43.060966  21.939034
#
# [172 rows x 5 columns]

# %%
data.to_csv('CHNS_pexam_pub_12_U24BU23U36_new.csv')
files.download('CHNS_pexam_pub_12_U24BU23U36_new.csv')

# %%
data1.plot(x ='x1', y='e', kind = 'scatter')
data1.plot(x ='x2', y='e', kind = 'scatter')
data1.plot(x ='x3', y='e', kind = 'scatter')

# %%
# เรียง data จากน้อยไปมากตาม y_hat
new_table_sort = data1.sort_values('y_hat')
new_table_sort.reset_index(inplace=True)
new_table_sort.drop(['index'], axis=1, inplace=True)
new_table_sort
# Out:
#       x1   x2   x3     y      y_hat          e
# 0    3.0  2.0  0.9  70.0  33.032631  36.967369
# 1    3.0  2.0  0.7  46.0  34.834748  11.165252
# 2    3.0  3.0  0.3  47.0  39.661926   7.338074
# 3    2.0  3.0  0.1  66.0  40.325258  25.674742
# 4    5.0  1.0  0.1  70.0  41.295729  28.704271
# 5   12.0  3.0  1.0  12.0  43.603585 -31.603585
# 6    7.0  2.0  0.2  50.0  43.895184   6.104816
# 7    3.0  8.0  0.1  56.0  47.578757   8.421243
# 8   10.0  3.0  0.2  54.0  48.534484   5.465516
# 9   10.0  4.0  0.1  60.0  50.658485   9.341515
# 10  10.0  4.0  0.1  52.0  50.658485   1.341515
# 11  10.0  5.0  0.2  63.0  50.980369  12.019631
# 12  15.0  1.0  0.1  43.0  52.683585  -9.683585
# 13  15.0  1.0  0.1  40.0  52.683585 -12.683585
# 14  23.0  1.0  0.5  54.0  58.189635  -4.189635
# 15  13.0  8.0  0.1  73.0  58.966613  14.033387
# 16  21.0  2.0  0.1  53.0  60.739241  -7.739241
# 17  10.0  5.0 -0.9  57.0  60.892015  -3.892015
# 18  24.0  3.0  0.3  42.0  63.576423 -21.576423
# 19  30.0  3.0  1.0  52.0  64.101726 -12.101726
# 20  30.0  1.0  0.5  49.0  66.161134 -17.161134
# 21  17.0  5.0 -0.9  42.0  68.863514 -26.863514

# %%
# กำหนด % การแบ่งข้อมูล
percent_data = 0.4

# %%
# แบ่งข้อมูลกลุ่มที่ 1
table_new1 = new_table_sort.iloc[:int(percent_data*new_table_sort.shape[0]) , :]
table_new1
# Out:
#      x1   x2   x3     y      y_hat          e
# 0   3.0  2.0  0.9  70.0  33.032631  36.967369
# 1   3.0  2.0  0.7  46.0  34.834748  11.165252
# 2   3.0  3.0  0.3  47.0  39.661926   7.338074
# 3   2.0  3.0  0.1  66.0  40.325258  25.674742
# 4   5.0  1.0  0.1  70.0  41.295729  28.704271
# 5  12.0  3.0  1.0  12.0  43.603585 -31.603585
# 6   7.0  2.0  0.2  50.0  43.895184   6.104816
# 7   3.0  8.0  0.1  56.0  47.578757   8.421243

# %%
# แบ่งข้อมูลกลุ่มที่ 1
table_new1 = new_table_sort.iloc[:int(percent_data*new_table_sort.shape[0]) , :]
y = table_new1['y']
x = table_new1[['x1', 'x2', 'x3']]
x = sm.add_constant(x)
model1 = sm.OLS(y, x).fit()

# หาค่า df กลุ่ม 1
DF1 = model1.df_resid + 1
SSE1 = model1.ssr
MSE1 = SSE1/DF1
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
DF1
# Out:
# 5.0

# %%
SSE1
# Out:
# 680.6925284978795

# %%
# แบ่งข้อมูลกลุ่มที่ 2
table_new2 = new_table_sort.iloc[int((1-percent_data)*new_table_sort.shape[0]): , :]
table_new2
# Out:
#       x1   x2   x3     y      y_hat          e
# 13  15.0  1.0  0.1  40.0  52.683585 -12.683585
# 14  23.0  1.0  0.5  54.0  58.189635  -4.189635
# 15  13.0  8.0  0.1  73.0  58.966613  14.033387
# 16  21.0  2.0  0.1  53.0  60.739241  -7.739241
# 17  10.0  5.0 -0.9  57.0  60.892015  -3.892015
# 18  24.0  3.0  0.3  42.0  63.576423 -21.576423
# 19  30.0  3.0  1.0  52.0  64.101726 -12.101726
# 20  30.0  1.0  0.5  49.0  66.161134 -17.161134
# 21  17.0  5.0 -0.9  42.0  68.863514 -26.863514

# %%
# แบ่งข้อมูลกลุ่มที่ 2
table_new2 = new_table_sort.iloc[int((1-percent_data)*new_table_sort.shape[0]): , :]
y = table_new2['y']
x = table_new2[['x1', 'x2', 'x3']]

# add constant to predictor variable
x = sm.add_constant(x)
# fit linear regression model
model2 = sm.OLS(y, x).fit()

# หาค่า df กลุ่ม 2
DF2 = model2.df_resid + 1
SSE2 = model2.ssr
MSE2 = SSE2/DF2
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
DF2
# Out:
# 6.0

# %%
SSE2
# Out:
# 319.27204582540355

# %%
# ค่าสถิติทดสอบ
GQ_test = (SSE2/DF2) / (SSE1/DF1)
GQ_test
# Out:
# 0.3908666939168044

# %%
# คำนวณค่า p-value
# pdf(x, dfn, dfd, loc=0, scale=1) : Probability density function
two_tailed = 2.0*(1.0-(ss.f.cdf(GQ_test, DF2, DF1)))
p_greater = ss.f.cdf(GQ_test, DF2, DF1)
p_less = 1.0-ss.f.cdf(GQ_test, DF2, DF1)

# %%
two_tailed
# Out:
# 1.7159643375244542

# %%
p_greater*2
# Out:
# 0.2840356624755457

# %%
p_less
# Out:
# 0.8579821687622271

# %% [markdown]
# ###### The two-tailed p-value equals: 0.1283
#
# ###### p( x < 0.2882 ) = 0.06417
# ###### p( x > 0.2882 ) = 0.9358
# ###### p( x < 0.2882 ) + p( x >3.7472) = 0.1283
# ###### Since p-value > α, H0 is not rejected. (0.1283 > 0.05)
#
# https://www.statskingdom.com/p_value.html

# %%
Significance = 0.05
if (p_greater*2) < Significance:
  print('Reject005=0 : Heteroscedasticity')
else:
  print('Reject005=1 : Homoscedasticity')
# Out:
# Reject005=1 : Homoscedasticity
